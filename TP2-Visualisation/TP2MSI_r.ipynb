# %% [markdown]
# # Rappel du sujet :
# <p>L’objectif du TP, avec le système R, est de réaliser une analyse
# bi-variable, et de trouver les variables qui permettent la
# meilleure reconnaissance d’un spécimen de type IRIS. </p>

# %% [markdown]
# # Question 1 :
# <p> Quel est le spécimen le plus mieux reconnu ? Justifiez votre
# réponse par : aggregate, boxplot, scatter plot. </p>

# %%
# Code réalisé par Alexandre-Lebas le 15/09/2021

# Question 1 : 

aggregate(Sepal.Length ~ Species, summary, data = iris)
# Out:
#   Species    Sepal.Length
# 1 setosa     4.3, 4.800, 5.0, 5.006, 5.2, 5.8
# 2 versicolor 4.9, 5.600, 5.9, 5.936, 6.3, 7.0
# 3 virginica  4.9, 6.225, 6.5, 6.588, 6.9, 7.9

# %%
aggregate(Sepal.Width ~ Species, summary, data = iris)
# Out:
#   Species    Sepal.Width
# 1 setosa     2.3, 3.200, 3.4, 3.428, 3.675, 4.4
# 2 versicolor 2.0, 2.525, 2.8, 2.770, 3.000, 3.4
# 3 virginica  2.2, 2.800, 3.0, 2.974, 3.175, 3.8

# %%
aggregate(Petal.Length ~ Species, summary, data = iris)
# Out:
#   Species    Petal.Length
# 1 setosa     1.0, 1.4, 1.50, 1.462, 1.575, 1.9
# 2 versicolor 3.0, 4.0, 4.35, 4.260, 4.600, 5.1
# 3 virginica  4.5, 5.1, 5.55, 5.552, 5.875, 6.9

# %%
aggregate(Petal.Width ~ Species, summary, data = iris)
# Out:
#   Species    Petal.Width
# 1 setosa     0.1, 0.2, 0.2, 0.246, 0.3, 0.6
# 2 versicolor 1.0, 1.2, 1.3, 1.326, 1.5, 1.8
# 3 virginica  1.4, 1.8, 2.0, 2.026, 2.3, 2.5

# %%
boxplot(Sepal.Length ~ Species, data = iris)
# Out:
# plot without title

# %%
boxplot(Sepal.Width ~ Species, data = iris)
# Out:
# plot without title

# %%
boxplot(Petal.Length ~ Species, data = iris)
# Out:
# plot without title

# %%
boxplot(Petal.Width ~ Species, data = iris)
# Out:
# plot without title

# %%
with(iris, plot(Sepal.Length, Sepal.Width, col = Species,pch = as.numeric(Species)))
# Out:
# plot without title

# %%
with(iris, plot(Petal.Length, Petal.Width, col = Species,pch = as.numeric(Species)))

#On remarque que le spécimen le mieux reconnu est le Setosa car on remarque que ses caractéristiques sont séparables linéairement des deux autres espèces
# Out:
# plot without title

# %% [markdown]
# <p>On remarque que le spécimen le mieux reconnu est le Setosa car on remarque que ses caractéristiques sont séparables linéairement des deux autres espèces</p>

# %% [markdown]
# # Question 2 :
# <p>Quelles sont les variables les plus discriminantes ?</p>

# %%
# Question 2 :

cor(iris[,1:4])
# Out:
#              Sepal.Length Sepal.Width Petal.Length Petal.Width
# Sepal.Length  1.0000000   -0.1175698   0.8717538    0.8179411
# Sepal.Width  -0.1175698    1.0000000  -0.4284401   -0.3661259
# Petal.Length  0.8717538   -0.4284401   1.0000000    0.9628654
# Petal.Width   0.8179411   -0.3661259   0.9628654    1.0000000

# %%
cov(iris[,1:4])
# Out:
#              Sepal.Length Sepal.Width Petal.Length Petal.Width
# Sepal.Length  0.6856935   -0.0424340   1.2743154    0.5162707
# Sepal.Width  -0.0424340    0.1899794  -0.3296564   -0.1216394
# Petal.Length  1.2743154   -0.3296564   3.1162779    1.2956094
# Petal.Width   0.5162707   -0.1216394   1.2956094    0.5810063

# %%
eigen(cov(iris[,1:4]))

# On remarque que les variables les plus discriminantes sont Petal.Lenght en première avant toutes les autres et ensuite Sepal.Lenght car ce sont celles qui ont les plus grandes valeurs dans les premiers vecteurs propres de la matrice de covariance.
# Out:
# eigen() decomposition
# $values
# [1] 4.22824171 0.24267075 0.07820950 0.02383509
#
# $vectors
#             [,1]        [,2]        [,3]       [,4]
# [1,]  0.36138659 -0.65658877 -0.58202985  0.3154872
# [2,] -0.08452251 -0.73016143  0.59791083 -0.3197231
# [3,]  0.85667061  0.17337266  0.07623608 -0.4798390
# [4,]  0.35828920  0.07548102  0.54583143  0.7536574

# %% [markdown]
# <p>On remarque que les variables les plus discriminantes sont Petal.Lenght en première avant toutes les autres et ensuite Sepal.Lenght car ce sont celles qui ont les plus grandes valeurs dans les premiers vecteurs propres de la matrice de covariance.</p>

# %% [markdown]
# # Question 3 :
# <p>Où observer des régressions linéaires ? Utiliser la Matrix of scatter plot</p>

# %%
# Question 3 : 

plot(iris, pch=20 , cex=1.5 , col="#69b3a2")

# On peut observer des régressions linéaires entre Petal.Lenght et Petal.Width On peu aussi remarquer une regression linéaire de moins bonne qualité entre Sepal Lenght et Petal Lenght ainsi que Petal Width et Sepal Lenght
# Out:
# plot without title

# %% [markdown]
# <p>On peut observer des régressions linéaires entre Petal.Lenght et Petal.Width On peu aussi remarquer une regression linéaire de moins bonne qualité entre Sepal Lenght et Petal Lenght ainsi que Petal Width et Sepal Lenght</p>

# %% [markdown]
# # Question 4 :
# <p>Visualiser en 3 d la relation iris, en scatterplot 3D (voir la
# fonction cloud de la librairie graphix)</p>

# %%
# Question 4 :

library(rgl)

# %%
data = iris

# %%
# Code inspiré de la page https://www.r-graph-gallery.com/3d_scatter_plot.html

mycolors <- c('royalblue1', 'darkcyan', 'oldlace')
data$color <- mycolors[ as.numeric(data$Species) ]

plot3d( 
  x=data$`Sepal.Length`, y=data$`Sepal.Width`, z=data$`Petal.Length`, 
  col = data$color, 
  type = 's', 
  radius = .1,
  xlab="Sepal Length", ylab="Sepal Width", zlab="Petal Length")

rglwidget() # Pour les notebooks
# Out:
# HTML widgets cannot be represented in plain text (need html)

# %% [markdown]
# # Question 5 :
# <p>Même question pour Interactve 3d scatter plot</p>

# %%
# Question 5 :

install.packages("magick")
# Out:
# Installation du package dans 'C:/Users/alex5/OneDrive/Documents/R/win-library/4.1'
# (car 'lib' n'est pas spécifié)
# package 'magick' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'magick'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problème lors de la copie de C:\Users\alex5\OneDrive\Documents\R\win-library\4.1\00LOCK\magick\libs\x64\magick.dll vers C:\Users\alex5\OneDrive\Documents\R\win-library\4.1\magick\libs\x64\magick.dll: Permission denied"
# Warning message:
# "restored 'magick'"
# The downloaded binary packages are in
# 	C:\Users\alex5\AppData\Local\Temp\RtmpqI1leD\downloaded_packages

# %%
library(magick)
# Out:
# Linking to ImageMagick 6.9.12.3
# Enabled features: cairo, freetype, fftw, ghostscript, heic, lcms, pango, raw, rsvg, webp
# Disabled features: fontconfig, x11

# %%
# Code inspiré de https://www.r-graph-gallery.com/3-r-animated-cube.html
colors <- c("royalblue1", "darkcyan", "oldlace")
data$color <- colors[ as.numeric( as.factor(data$Species) ) ]

plot3d( iris[,1], iris[,2], iris[,3], col = data$color, type = "s", radius = .2 )

play3d( spin3d( axis = c(0, 0, 1), rpm = 20), duration = 10 )
# Out:
# Error in play3d(spin3d(axis = c(0, 0, 1), rpm = 20), duration = 10): cur3d() != 0 n'est pas TRUE
# Traceback:
#
# 1. play3d(spin3d(axis = c(0, 0, 1), rpm = 20), duration = 10)
# 2. stopifnot(cur3d() != 0)

# %% [markdown]
# # Question 6 :
# <p>Quelles sont les fleurs les plus proches ? (utiliser la heatmap
# et level plot)</p>

# %%
# Question 6 : 

data = iris
data$Species = as.numeric(data$Species)
print(data)
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1            5.1         3.5          1.4         0.2       1
# 2            4.9         3.0          1.4         0.2       1
# 3            4.7         3.2          1.3         0.2       1
# 4            4.6         3.1          1.5         0.2       1
# 5            5.0         3.6          1.4         0.2       1
# 6            5.4         3.9          1.7         0.4       1
# 7            4.6         3.4          1.4         0.3       1
# 8            5.0         3.4          1.5         0.2       1
# 9            4.4         2.9          1.4         0.2       1
# 10           4.9         3.1          1.5         0.1       1
# 11           5.4         3.7          1.5         0.2       1
# 12           4.8         3.4          1.6         0.2       1
# 13           4.8         3.0          1.4         0.1       1
# 14           4.3         3.0          1.1         0.1       1
# ...

# %%
heatmap(as.matrix(data))

# On remarque les fleurs les plus proches sont les versicolors et les virginicas.
# Out:
# plot without title

# %% [markdown]
# On remarque les fleurs les plus proches sont les versicolors et les virginicas.
